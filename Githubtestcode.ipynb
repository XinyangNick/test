# %%
print("Hello this is the first time using githubdesktop")
# Out:
# Hello this is the first time using githubdesktop

# %%
import pandas as pd

# %%
x = pd.Series(range(1,11))
y = x ** 2

# %%
df = pd.DataFrame([x, y])
df.plot()
# Out:
# <AxesSubplot:>
